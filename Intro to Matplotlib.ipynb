# %% [markdown]
# ## Intro to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot ()
# Out:
# []

# %%
x = [4,6,8,9]
y = [1,2,4,5]
plt.plot (x, y)

# %%
fig, ax = plt.subplots ()
ax.plot (x,y)

# %%
ax
# Out:
# <Axes: >
